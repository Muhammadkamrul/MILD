# %%
#Generate dataset
# !python -m generate_hard_dataset \
  --out data/hard/dataset.csv \
  --minutes 200000 \
  --seed 42 \
  --p_nonlinear 0.60 \
  --p_codrift 0.20 \
  --p_independent 0.20

# %%
#Run MILD
# !python -m run_hybrid_experiment \
  --data data/hard/dataset.csv \
  --outdir out_final/hard/hybrid_hard \
  --folds 11 --epochs 30 --batch 512 --fp_budget 1 \
  --gate_supervise 0.7 --gate_sparsity 0.005 \
  --distill_alpha 0.9 --temp 2.0 --gate_teacher 0.7
# Out:
# 2025-10-26 17:22:17.888027: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-26 17:22:17.915374: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-26 17:22:18.797116: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
#
# --- Fold 1/11: test [0:18181) ---
# ...

# %%
#Run MLP Baseline
# !python -m baseline_NEW_MLP \
  --data data/hard/dataset.csv \
  --outdir out_final/hard/baselines_NEW_MLP \
  --fp_budget 1 --folds 11
# Out:
# 2025-10-26 17:47:13.514533: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-26 17:47:13.544924: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-26 17:47:14.544700: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
#
# --- Fold 1/11: test [0:18181) ---
# ...

# %%
#Run Other Baselines
# !python -m baselines_multiintent_gem_corrected \
  --data data/hard/dataset.csv \
  --outdir out_final/hard/baselines_F2 \
  --fp_budget 1 --folds 11
# Out:
# 2025-10-26 18:30:39.671785: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-26 18:30:39.700579: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-26 18:30:40.557627: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
#
# --- Fold 1/11: test [0:18181) ---
# ...

# %%
#Generate Plots
# !python -m multi_horizon_and_shap \
  --data data/hard/dataset.csv \
  --outdir out_final/operational_intelligence \
  --horizons 120 60 30 \
  --fold 3 --folds 5 \
  --intent telemetry \
  --epochs 30 --batch 512 \
  --fp_budget 1 \
  --gate_supervise 0.7 --gate_sparsity 0.005 \
  --distill_alpha 0.9 --temp 2.0 --gate_teacher 0.7

# %%
#Generate Plots
# !python -m paper_plots \
  --snapshot_csv data/hard/dataset.csv \
  --events_json data/hard/events_by_intent.json \
  --timeseries_csv out_final/hard/hybrid_hard/fold2_timeseries.csv \
  --intent telemetry \
  --outdir out_final/paper_figs

# %%
#Generate Plots
val = 18
# !python -m final_plots_gpt --outdir out_final/plots_gpt --label-size {val} --tick-size {val} --legend-size {val}
